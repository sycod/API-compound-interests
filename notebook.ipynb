# %% [markdown]
# # Initialisation

# %%
import yaml
import numpy as np
import pandas as pd
import plotly.express as px

# %%
# CONFIG
# Load config file
with open("config.yaml", "r", encoding="utf-8") as f:
    config = yaml.safe_load(f)

# %%
# Setup
k = config["k"]["init"]
rate = config["rate"]["init"]
ann_savings = config["ann_savings"]["init"]
DURATION = config["duration_yrs"]
TAX = config["tax"]

# %%
# 🚧
rate = 0.1 ; ann_savings = 1000

# %%
df = pd.DataFrame(columns=["annee", "epargne", "brut", "epargne_cum", "comp_brut", "capital", "cum_net", "mensuel_net"])

# %% [markdown]
# # Années

# %%
df["annee"] = range(DURATION)
df["annee"] = df["annee"] + 1

# %% [markdown]
# # Épargne cumulée

# %%
df["epargne"] = k + ((df["annee"] - 1) * ann_savings)

# %% [markdown]
# # Intérêts annuels bruts

# %% [markdown]
# Chaque nouvelle année commence avec le **capital de départ** + l'**épargne** réalisée dans l'anée + les **intérêts de l'année passée**
#
# Ce sont ces intérêts qui, réinjectés dans le calcul des intérêts de l'année en cours, forment les **intérêts composés**.

# %%
brut = [k * rate]
for i in range(1, len(df.index)):
    

    n = brut[i-1]
    brut.append(n)


#     cum = df.brut.loc[:i-1].cumsum()[i-1]
df["brut"] = brut
df["brut"] = round(df["brut"], 0).astype(int)

# %%
display(f"{k = }, {rate = }, {ann_savings = }, {DURATION = }, {TAX = }")
display(df)
# Out:
# 'k = 2000, rate = 0.1, ann_savings = 1000, DURATION = 40, TAX = 0.3'
#     annee  epargne    brut epargne_cum comp_brut capital cum_net mensuel_net
# 0       1     2000     200         NaN       NaN     NaN     NaN         NaN
# 1       2     3000    3200         NaN       NaN     NaN     NaN         NaN
# 2       3     4000    7200         NaN       NaN     NaN     NaN         NaN
# 3       4     5000   12200         NaN       NaN     NaN     NaN         NaN
# 4       5     6000   18200         NaN       NaN     NaN     NaN         NaN
# 5       6     7000   25200         NaN       NaN     NaN     NaN         NaN
# 6       7     8000   33200         NaN       NaN     NaN     NaN         NaN
# 7       8     9000   42200         NaN       NaN     NaN     NaN         NaN
# 8       9    10000   52200         NaN       NaN     NaN     NaN         NaN
# 9      10    11000   63200         NaN       NaN     NaN     NaN         NaN
# 10     11    12000   75200         NaN       NaN     NaN     NaN         NaN
# 11     12    13000   88200         NaN       NaN     NaN     NaN         NaN
# 12     13    14000  102200         NaN       NaN     NaN     NaN         NaN
# 13     14    15000  117200         NaN       NaN     NaN     NaN         NaN
# 14     15    16000  133200         NaN       NaN     NaN     NaN         NaN
# 15     16    17000  150200         NaN       NaN     NaN     NaN         NaN
# 16     17    18000  168200         NaN       NaN     NaN     NaN         NaN
# 17     18    19000  187200         NaN       NaN     NaN     NaN         NaN
# 18     19    20000  207200         NaN       NaN     NaN     NaN         NaN
# 19     20    21000  228200         NaN       NaN     NaN     NaN         NaN
# 20     21    22000  250200         NaN       NaN     NaN     NaN         NaN
# 21     22    23000  273200         NaN       NaN     NaN     NaN         NaN
# 22     23    24000  297200         NaN       NaN     NaN     NaN         NaN
# 23     24    25000  322200         NaN       NaN     NaN     NaN         NaN
# 24     25    26000  348200         NaN       NaN     NaN     NaN         NaN
# 25     26    27000  375200         NaN       NaN     NaN     NaN         NaN
# 26     27    28000  403200         NaN       NaN     NaN     NaN         NaN
# 27     28    29000  432200         NaN       NaN     NaN     NaN         NaN
# 28     29    30000  462200         NaN       NaN     NaN     NaN         NaN
# 29     30    31000  493200         NaN       NaN     NaN     NaN         NaN
# 30     31    32000  525200         NaN       NaN     NaN     NaN         NaN
# 31     32    33000  558200         NaN       NaN     NaN     NaN         NaN
# 32     33    34000  592200         NaN       NaN     NaN     NaN         NaN
# 33     34    35000  627200         NaN       NaN     NaN     NaN         NaN
# 34     35    36000  663200         NaN       NaN     NaN     NaN         NaN
# 35     36    37000  700200         NaN       NaN     NaN     NaN         NaN
# 36     37    38000  738200         NaN       NaN     NaN     NaN         NaN
# 37     38    39000  777200         NaN       NaN     NaN     NaN         NaN
# 38     39    40000  817200         NaN       NaN     NaN     NaN         NaN
# 39     40    41000  858200         NaN       NaN     NaN     NaN         NaN

# %% [markdown]
# # Capital

# %%
df["capital"] = df["comp_brut"] + df["epargne_cum"]

# %% [markdown]
# # Intérêts cumulés nets annuels

# %%
df["cum_net"] = round(df["cum_brut"] * (1 - TAX), 0).astype(int)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cum_brut'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[226], line 1
# ----> 1 df["cum_net"] = round(df["cum_brut"] * (1 - TAX), 0).astype(int)
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/indexes/base.py:3809, in Index.get_loc(self, key)
#    3804     if isinstance(casted_key, slice) or (
#    3805         isinstance(casted_key, abc.Iterable)
#    3806         and any(isinstance(x, slice) for x in casted_key)
#    3807     ):
#    3808         raise InvalidIndexError(key)
# -> 3809     raise KeyError(key) from err
#    3810 except TypeError:
#    3811     # If we have a listlike key, _check_indexing_error will raise
#    3812     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3813     #  the TypeError.
#    3814     self._check_indexing_error(key)
#
# KeyError: 'cum_brut'

# %% [markdown]
# # Intérêts nets mensuels

# %%
df["mensuel_net"] = round(df["cum_net"] / 12, 0).astype(int)
