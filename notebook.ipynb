# %% [markdown]
# # Initialisation

# %%
import yaml
import numpy as np
import pandas as pd
import plotly.express as px

# %%
# CONFIG
# Load config file
with open("config.yaml", "r", encoding="utf-8") as f:
    config = yaml.safe_load(f)

# %%
# Setup
k = config["k"]["init"]
rate = config["rate"]["init"]
ann_savings = config["ann_savings"]["init"]
DURATION = config["duration_yrs"]
TAX = config["tax"]

# %%
# 🚧
rate = 0.1 ; ann_savings = 1000

# %%
df = pd.DataFrame(columns=["annee", "epargne_cum", "brut", "cum_brut", "comp_brut", "capital", "cum_net", "mensuel_net"])

# %% [markdown]
# # Années

# %%
df["annee"] = range(DURATION)
df["annee"] = df["annee"] + 1

# %% [markdown]
# # Épargne cumulée

# %%
df["epargne_cum"] = k + ((df["annee"] - 1) * ann_savings)

# %% [markdown]
# # Intérêts annuels bruts

# %%
df["brut"] = round((df["epargne_cum"]) * (rate), 0).astype(int)

# %% [markdown]
# # Intérêts cumulés bruts

# %%
df["cum_brut"] = df["brut"].cumsum()

# %% [markdown]
# # Intérêts composés bruts

# %%
df["comp_brut"] = df["cum_brut"]

# %%
display(f"{k = }, {rate = }, {ann_savings = }, {DURATION = }, {TAX = }")
display(df)
# Out:
# 'k = 2000, rate = 0.1, ann_savings = 1000, DURATION = 40, TAX = 0.3'
#     annee  epargne_cum  brut  cum_brut comp_brut capital cum_net mensuel_net
# 0       1         2000   200       200       NaN     NaN     NaN         NaN
# 1       2         3000   300       500       NaN     NaN     NaN         NaN
# 2       3         4000   400       900       NaN     NaN     NaN         NaN
# 3       4         5000   500      1400       NaN     NaN     NaN         NaN
# 4       5         6000   600      2000       NaN     NaN     NaN         NaN
# 5       6         7000   700      2700       NaN     NaN     NaN         NaN
# 6       7         8000   800      3500       NaN     NaN     NaN         NaN
# 7       8         9000   900      4400       NaN     NaN     NaN         NaN
# 8       9        10000  1000      5400       NaN     NaN     NaN         NaN
# 9      10        11000  1100      6500       NaN     NaN     NaN         NaN
# ...

# %% [markdown]
# # Capital

# %%
df["capital"] = df["comp_brut"] + df["epargne_cum"]

# %% [markdown]
# # Intérêts cumulés nets annuels

# %%
df["cum_net"] = round(df["cum_brut"] * (1 - TAX), 0).astype(int)

# %% [markdown]
# # Intérêts nets mensuels

# %%
df["mensuel_net"] = round(df["cum_net"] / 12, 0).astype(int)
